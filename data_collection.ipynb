# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %% [markdown]
# # Load Files

# %%
args = sys.argv
assert(len(args[1:]) == 8), "Must include all 8 scenario files"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d5c33e362c7e> in <module>
# ----> 1 args = sys.argv
#       2 assert(len(args[1:]) == 8), "Must include all 8 scenario files"
#
# NameError: name 'sys' is not defined

# %% [markdown]
# ## Scenario 1 Collection

# %%
# scenario1_path = args[1]
scenario1_path = "~/Downloads/output-scenario-1.csv"
s1 = pd.read_csv(scenario1_path)

# %%
# effect from velocity
vel = s1[
    (s1['byWitnessRep'] == False) & 
    (s1['byNumWitnesses'] == False) & 
    (s1['kNumWitnesses'] == 2.0) &
    (s1['useQuartiles'] == False)
]
vel[['velocity', 'operatingError', 'reportingError']].to_csv("0_velocity.csv")
# Out:
#          runtime  velocity  byWitnessRep  byNumWitnesses  kNumWitnesses  \
# 72      0.115933       0.1         False           False            2.0
# 73      0.131539       0.2         False           False            2.0
# 74      0.115951       0.3         False           False            2.0
# 75      0.131041       0.4         False           False            2.0
# 76      0.131249       0.5         False           False            2.0
# ...          ...       ...           ...             ...            ...
# 240155  0.126066       0.5         False           False            2.0
# 240156  0.130923       0.6         False           False            2.0
# 240157  0.118958       0.7         False           False            2.0
# 240158  0.115707       0.8         False           False            2.0
# 240159  0.122614       0.9         False           False            2.0
#
#         useQuartiles  numVehicles  minRecipients  maxRecipients  \
# 72             False          100              5             30
# 73             False          100              5             30
# 74             False          100              5             30
# 75             False          100              5             30
# 76             False          100              5             30
# ...              ...          ...            ...            ...
# 240155         False          100              5             30
# 240156         False          100              5             30
# 240157         False          100              5             30
# 240158         False          100              5             30
# 240159         False          100              5             30
#
#         propWitnesses  propNormal  broadcastNoise  witnessNoise  useMalOp  \
# 72                0.5         0.9            0.05          0.05     False
# 73                0.5         0.9            0.05          0.05     False
# 74                0.5         0.9            0.05          0.05     False
# 75                0.5         0.9            0.05          0.05     False
# 76                0.5         0.9            0.05          0.05     False
# ...               ...         ...             ...           ...       ...
# 240155            0.5         0.9            0.05          0.05     False
# 240156            0.5         0.9            0.05          0.05     False
# 240157            0.5         0.9            0.05          0.05     False
# 240158            0.5         0.9            0.05          0.05     False
# 240159            0.5         0.9            0.05          0.05     False
#
#         useMalRep  numTurns  percTransaction  percMalicious  \
# 72          False      5000              0.9  percMalicious
# 73          False      5000              0.9  percMalicious
# 74          False      5000              0.9  percMalicious
# 75          False      5000              0.9  percMalicious
# 76          False      5000              0.9  percMalicious
# ...           ...       ...              ...            ...
# 240155      False      5000              0.9  percMalicious
# 240156      False      5000              0.9  percMalicious
# 240157      False      5000              0.9  percMalicious
# 240158      False      5000              0.9  percMalicious
# 240159      False      5000              0.9  percMalicious
#
#                                           operatingScores  \
# 72      {AV_0(MAL): 0.15075909835492315, AV_1(MAL): 0....
# 73      {AV_0(MAL): 0.164429529022895, AV_1(MAL): 0.08...
# 74      {AV_0(MAL): 0.14582869647484983, AV_1(MAL): 0....
# 75      {AV_0(MAL): 0.08964167269594217, AV_1(MAL): 0....
# 76      {AV_0(MAL): 0.05338781659759081, AV_1(MAL): 0....
# ...                                                   ...
# 240155  {AV_0(MAL): 0.2608047692161201, AV_1(MAL): 0.1...
# 240156  {AV_0(MAL): 0.23618327487062124, AV_1(MAL): 0....
# 240157  {AV_0(MAL): 0.10682905204290996, AV_1(MAL): 0....
# 240158  {AV_0(MAL): 0.2667162424908326, AV_1(MAL): 0.4...
# 240159  {AV_0(MAL): 0.45000198022500015, AV_1(MAL): 0....
#
#                                           reportingScores
# 72      {AV_0(MAL): 0.2996379035494311, AV_1(MAL): 0.3...
# 73      {AV_0(MAL): 0.4215851064827354, AV_1(MAL): 0.3...
# 74      {AV_0(MAL): 0.4087079086732331, AV_1(MAL): 0.2...
# 75      {AV_0(MAL): 0.31963164615606315, AV_1(MAL): 0....
# 76      {AV_0(MAL): 0.8030315915350666, AV_1(MAL): 0.2...
# ...                                                   ...
# 240155  {AV_0(MAL): 0.2850450038082102, AV_1(MAL): 0.2...
# 240156  {AV_0(MAL): 0.337607492222036, AV_1(MAL): 0.30...
# 240157  {AV_0(MAL): 0.2410381967986279, AV_1(MAL): 0.3...
# 240158  {AV_0(MAL): 0.2070784670408483, AV_1(MAL): 0.1...
# 240159  {AV_0(MAL): 0.47728347501970836, AV_1(MAL): 0....
#
# [10017 rows x 20 columns]

# %%
# effect from byWitnessRep
bWR = s1[
    (s1['velocity'] == 0.1) & 
    (s1['byNumWitnesses'] == False) & 
    (s1['kNumWitnesses'] == 2.0) &
    (s1['useQuartiles'] == False)
]
bWR[['byWitnessRep', 'operatingError', 'reportingError']].to_csv("1_byWitnessRep.csv")

# %%
# effect from byNumWitnesses
bNW = s1[
    (s1['velocity'] == 0.1) & 
    (s1['byWitnessRep'] == False) & 
    (s1['kNumWitnesses'] == 2.0) &
    (s1['useQuartiles'] == False)
]
bNW[['byNumWitnesses', 'operatingError', 'reportingError']].to_csv("2_byNumWitnesses.csv")

# %%
# effect from kNumWitnesses
kNW = s1[
    (s1['velocity'] == 0.1) & 
    (s1['byWitnessRep'] == False) & 
    (s1['byNumWitnesses'] == False) &
    (s1['useQuartiles'] == False)
][['kNumWitnesses', 'operatingError', 'reportingError']]
kNW.to_csv("3_kNumWitnesses.csv")

# %%
# effect from useQuartiles
useQuartiles = s1[
    (s1['velocity'] == 0.1) & 
    (s1['byWitnessRep'] == False) & 
    (s1['byNumWitnesses'] == False) &
    (s1['kNumWitnesses'] == 2.0) 
][['useQuartiles', 'operatingError', 'reportingError']]
useQuartiles.to_csv("4_useQuartiles.csv")

# %% [markdown]
# ## Scenario 2 Collection

# %%
scenario2_path = args[2]
s2 = pd.read_csv(scenario2_path)

# %%
# high concentration of malicious vehicles
malEnv = s2[
    (s2['velocity'] == 0.1) & 
    (s2['byWitnessRep'] == False) & 
    (s2['byNumWitnesses'] == False) &
    (s2['kNumWitnesses'] == 2.0) &
    (s2['useQuartiles'] == False)
][['propNormal', 'operatingError', 'reportingError']]
malEnv.to_csv("5_malEnv.csv")

# %% [markdown]
# ## Scenario 3 Collection

# %%
scenario3_path = args[3]
s3 = pd.read_csv(scenario3_path)

# %%
# high noise environment
highNoise = s3[
    (s3['velocity'] == 0.1) & 
    (s3['byWitnessRep'] == False) & 
    (s3['byNumWitnesses'] == False) &
    (s3['kNumWitnesses'] == 2.0) &
    (s3['useQuartiles'] == False)
][['broadcastNoise', 'witnessNoise', 'operatingError', 'reportingError']]
highNoise.to_csv("6_highNoise.csv")

# %% [markdown]
# ## Scenario 4 Collection

# %%
scenario4_path = args[4]
s4 = pd.read_csv(scenario4_path)

# %%
# large population
largePopulation = s4[
    (s4['velocity'] == 0.1) & 
    (s4['byWitnessRep'] == False) & 
    (s4['byNumWitnesses'] == False) &
    (s4['kNumWitnesses'] == 2.0) &
    (s4['useQuartiles'] == False)
][['numVehicles', 'operatingError', 'reportingError']]
largePopulation.to_csv("7_largePopulation.csv")

# %% [markdown]
# ## Scenario 5 Collection

# %%
scenario5_path = args[5]
s5 = pd.read_csv(scenario5_path)

# %%
# dense population
densePopulation = s5[
    (s5['velocity'] == 0.1) & 
    (s5['byWitnessRep'] == False) & 
    (s5['byNumWitnesses'] == False) &
    (s5['kNumWitnesses'] == 2.0) &
    (s5['useQuartiles'] == False)
][['propWitnesses', 'percTransaction', 'operatingError', 'reportingError']]
densePopulation.to_csv("8_densePopulation.csv")

# %% [markdown]
# ## Scenario 6 Collection

# %%
scenario6_path = args[6]
s6 = pd.read_csv(scenario6_path)

# %%
# use malicious operating and reporting vehicles
useMalOpRep = s6[
    (s6['velocity'] == 0.1) & 
    (s6['byWitnessRep'] == False) & 
    (s6['byNumWitnesses'] == False) &
    (s6['kNumWitnesses'] == 2.0) &
    (s6['useQuartiles'] == False)
][['useMalOp', 'useMalRep', 'operatingError', 'reportingError']]
useMalOpRep.to_csv("9_useMalOpRep.csv")

# %% [markdown]
# ## Scenario 7 Collection

# %%
scenario7_path = args[7]
s7 = pd.read_csv(scenario7_path)

# %%
# different frequency of malicious vehicle transactions
malFreq = s7[
    (s7['velocity'] == 0.1) & 
    (s7['byWitnessRep'] == False) & 
    (s7['byNumWitnesses'] == False) &
    (s7['kNumWitnesses'] == 2.0) &
    (s7['useQuartiles'] == False)
][['percMalicious', 'operatingError', 'reportingError']]
malFreq.to_csv("10_malFreq.csv")

# %% [markdown]
# ## Scenario 8 Collection

# %%
scenario8_path = args[8]
s8 = pd.read_csv(scenario8_path)

# %%
# sparse population
sparsePop = s8[
    (s8['velocity'] == 0.1) & 
    (s8['byWitnessRep'] == False) & 
    (s8['byNumWitnesses'] == False) &
    (s8['kNumWitnesses'] == 2.0) &
    (s8['useQuartiles'] == False)
][['numVehicles', 'minRecipients', 'maxRecipients', 'operatingError', 'reportingError']]
sparsePop.to_csv("10_malFreq.csv")
